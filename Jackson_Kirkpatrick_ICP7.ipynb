# %% [markdown]
# <a href="https://colab.research.google.com/github/Kirknasty54/Jackson_Kirkpatrick_ICP7/blob/main/Jackson_Kirkpatrick_ICP7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple CNN model for CIFAR-10
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import max_norm
from keras.optimizers import SGD
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras import utils
#from keras import backend as K
#K.set_image_dim_ordering('th')

# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
# one hot encode outputs
y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)
num_classes = y_test.shape[1]
# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
epochs = 10
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        896
#
#  dropout_7 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_5 (Dense)             (None, 512)               4194816
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4210090 (16.06 MB)
# Trainable params: 4210090 (16.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/10
# 1563/1563 [==============================] - 216s 137ms/step - loss: 1.7142 - accuracy: 0.3796 - val_loss: 1.4251 - val_accuracy: 0.4823
# Epoch 2/10
# 1563/1563 [==============================] - 216s 138ms/step - loss: 1.3878 - accuracy: 0.5000 - val_loss: 1.2569 - val_accuracy: 0.5489
# Epoch 3/10
# 1563/1563 [==============================] - 209s 134ms/step - loss: 1.2212 - accuracy: 0.5635 - val_loss: 1.1109 - val_accuracy: 0.5981
# Epoch 4/10
# 1563/1563 [==============================] - 208s 133ms/step - loss: 1.0926 - accuracy: 0.6107 - val_loss: 1.0933 - val_accuracy: 0.6162
# Epoch 5/10
# 1563/1563 [==============================] - 212s 135ms/step - loss: 0.9912 - accuracy: 0.6499 - val_loss: 1.0418 - val_accuracy: 0.6348
# Epoch 6/10
# 1563/1563 [==============================] - 211s 135ms/step - loss: 0.8877 - accuracy: 0.6865 - val_loss: 1.0247 - val_accuracy: 0.6416
# Epoch 7/10
# 1563/1563 [==============================] - 209s 133ms/step - loss: 0.7968 - accuracy: 0.7180 - val_loss: 1.0207 - val_accuracy: 0.6491
# Epoch 8/10
# 1563/1563 [==============================] - 213s 136ms/step - loss: 0.7179 - accuracy: 0.7479 - val_loss: 0.9946 - val_accuracy: 0.6668
# Epoch 9/10
# 1563/1563 [==============================] - 210s 135ms/step - loss: 0.6499 - accuracy: 0.7728 - val_loss: 0.9982 - val_accuracy: 0.6733
# Epoch 10/10
# 1563/1563 [==============================] - 212s 136ms/step - loss: 0.5737 - accuracy: 0.7944 - val_loss: 1.0922 - val_accuracy: 0.6561
# Accuracy: 65.61%

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0
# one hot encode outputs
y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)
num_classes = y_test.shape[1]
# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=max_norm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=max_norm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
# Compile model
epochs = 10
lrate = 0.01
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)        896
#
#  dropout_9 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        18496
#
#  dropout_10 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_11 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 1024)              2098176
#
#  dropout_12 (Dropout)        (None, 1024)              0
#
#  dense_8 (Dense)             (None, 512)               524800
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/10
# 1563/1563 [==============================] - 396s 252ms/step - loss: 1.8054 - accuracy: 0.3369 - val_loss: 1.6211 - val_accuracy: 0.3939
# Epoch 2/10
# 1563/1563 [==============================] - 391s 250ms/step - loss: 1.3782 - accuracy: 0.5031 - val_loss: 1.3206 - val_accuracy: 0.5185
# Epoch 3/10
# 1563/1563 [==============================] - 392s 251ms/step - loss: 1.1694 - accuracy: 0.5835 - val_loss: 1.0567 - val_accuracy: 0.6308
# Epoch 4/10
# 1563/1563 [==============================] - 393s 251ms/step - loss: 1.0117 - accuracy: 0.6401 - val_loss: 0.9657 - val_accuracy: 0.6641
# Epoch 5/10
# 1563/1563 [==============================] - 400s 256ms/step - loss: 0.8864 - accuracy: 0.6864 - val_loss: 0.9443 - val_accuracy: 0.6750
# Epoch 6/10
# 1563/1563 [==============================] - 392s 251ms/step - loss: 0.7918 - accuracy: 0.7230 - val_loss: 0.8285 - val_accuracy: 0.7160
# Epoch 7/10
# 1563/1563 [==============================] - 393s 251ms/step - loss: 0.7277 - accuracy: 0.7460 - val_loss: 0.8508 - val_accuracy: 0.7078
# Epoch 8/10
# 1563/1563 [==============================] - 396s 253ms/step - loss: 0.6704 - accuracy: 0.7637 - val_loss: 0.7811 - val_accuracy: 0.7336
# Epoch 9/10
# 1563/1563 [==============================] - 396s 254ms/step - loss: 0.6184 - accuracy: 0.7835 - val_loss: 0.8168 - val_accuracy: 0.7280
# Epoch 10/10
# 1563/1563 [==============================] - 392s 251ms/step - loss: 0.5780 - accuracy: 0.7974 - val_loss: 0.7695 - val_accuracy: 0.7448
# Accuracy: 74.48%

# %%
import matplotlib.pyplot as plt
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = epochs, batch_size = 32)

# Predict the first 4 images
predictions = model.predict(X_test)

# Convert predictions to class labels
predicted_labels = numpy.argmax(predictions, axis=1)

# Convert one-hot encoded labels to class labels
actual_labels = numpy.argmax(y_test[:4], axis=1)

# Compare and print the results
for i in range(4):
    print(f"Predicted Label: {predicted_labels[i]}, Actual Label: {actual_labels[i]}")

plt.plot(history.history['accuracy'])
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 390s 249ms/step - loss: 0.5421 - accuracy: 0.8116 - val_loss: 0.7764 - val_accuracy: 0.7378
# Epoch 2/10
# 1563/1563 [==============================] - 393s 252ms/step - loss: 0.5112 - accuracy: 0.8219 - val_loss: 0.7822 - val_accuracy: 0.7441
# Epoch 3/10
# 1563/1563 [==============================] - 389s 249ms/step - loss: 0.4976 - accuracy: 0.8265 - val_loss: 0.7783 - val_accuracy: 0.7445
# Epoch 4/10
# 1563/1563 [==============================] - 394s 252ms/step - loss: 0.4773 - accuracy: 0.8352 - val_loss: 0.7673 - val_accuracy: 0.7516
# Epoch 5/10
# 1563/1563 [==============================] - 393s 252ms/step - loss: 0.4689 - accuracy: 0.8367 - val_loss: 0.7849 - val_accuracy: 0.7494
# Epoch 6/10
# 1563/1563 [==============================] - 391s 250ms/step - loss: 0.4607 - accuracy: 0.8396 - val_loss: 0.8365 - val_accuracy: 0.7377
# Epoch 7/10
# 1563/1563 [==============================] - 393s 251ms/step - loss: 0.4516 - accuracy: 0.8449 - val_loss: 0.8372 - val_accuracy: 0.7323
# Epoch 8/10
# 1563/1563 [==============================] - 398s 255ms/step - loss: 0.4500 - accuracy: 0.8459 - val_loss: 0.8602 - val_accuracy: 0.7243
# Epoch 9/10
# 1563/1563 [==============================] - 399s 255ms/step - loss: 0.4455 - accuracy: 0.8471 - val_loss: 0.8313 - val_accuracy: 0.7343
# Epoch 10/10
# 1563/1563 [==============================] - 390s 249ms/step - loss: 0.4394 - accuracy: 0.8501 - val_loss: 0.7819 - val_accuracy: 0.7441
# 313/313 [==============================] - 19s 59ms/step
# Predicted Label: 3, Actual Label: 3
# Predicted Label: 8, Actual Label: 8
# Predicted Label: 8, Actual Label: 8
# Predicted Label: 8, Actual Label: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-281cb433e322> in <cell line: 18>()
#      16
#      17 plt.plot(history.history['accuracy'])
# ---> 18 plt.plot(history.history['val_acc'])
#      19 plt.title('Model accuracy')
#      20 plt.ylabel('Accuracy')
#
# KeyError: 'val_acc'

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
